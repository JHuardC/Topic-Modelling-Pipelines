# %%
import pandas as pd

# %%
column_names = [
    'action', 
    'background', 
    'additional_details', 
    'created_at', 
    'moderation_threshold_reached_at', 
    'opened_at', 
    'updated_at', 
    'topics', 
    'state'
]
df = pd.read_csv(r'data/all_petitions_data.csv', names = column_names)

# %%
df.dtypes
# Out:
# action                             object
# background                         object
# additional_details                 object
# created_at                         object
# moderation_threshold_reached_at    object
# opened_at                          object
# updated_at                         object
# topics                             object
# state                              object
# dtype: object

# %%
df['created_at'].head(1)
# Out:
# 0    2020-03-02T12:06:20.235Z
# Name: created_at, dtype: object

# %%
df = df[['created_at', 'action', 'background', 'additional_details', 'topics']]

# %%
df.head()
# Out:
#                  created_at  \
# 0  2020-03-02T12:06:20.235Z
# 1  2020-03-03T11:21:56.566Z
# 2  2020-03-03T11:22:53.628Z
# 3  2020-03-03T11:23:13.336Z
# 4  2020-03-03T11:23:23.361Z
#
#                                               action  \
# 0  Protect the Environment – support carbon neutr...
# 1  Bring Hailsham’s roads back to a their former ...
# 2  Give holiday caravan/lodge owners the same sta...
# 3  Increase the criteria for a successful referen...
# 4  Allow conference speakers to be able to speak ...
#
#                                           background  \
# 0  In November 2019, Members of the UK Youth Parl...
# 1  “My aim is to get Hailsham streets and roads b...
# 2  Owners of holiday caravans and lodges need the...
# 3  Referendums can and have been deeply divisive,...
# 4  As of right now, you require a Tier 5 visa to ...
#
#                                   additional_details topics
# 0  To preserve this world for the next generation...     []
# 1  I am wanting to start a petition because the r...     []
# 2  As a multi-million pound consumer industry wit...     []
# 3  I propose increasing the threshold to 60%+ of ...     []
# 4  This is a negative for the country as a whole ...     []

# %%
df['created_at'] = pd.to_datetime(df['created_at'])

# %%
df.head()
# Out:
#                         created_at  \
# 0 2020-03-02 12:06:20.235000+00:00
# 1 2020-03-03 11:21:56.566000+00:00
# 2 2020-03-03 11:22:53.628000+00:00
# 3 2020-03-03 11:23:13.336000+00:00
# 4 2020-03-03 11:23:23.361000+00:00
#
#                                               action  \
# 0  Protect the Environment – support carbon neutr...
# 1  Bring Hailsham’s roads back to a their former ...
# 2  Give holiday caravan/lodge owners the same sta...
# 3  Increase the criteria for a successful referen...
# 4  Allow conference speakers to be able to speak ...
#
#                                           background  \
# 0  In November 2019, Members of the UK Youth Parl...
# 1  “My aim is to get Hailsham streets and roads b...
# 2  Owners of holiday caravans and lodges need the...
# 3  Referendums can and have been deeply divisive,...
# 4  As of right now, you require a Tier 5 visa to ...
#
#                                   additional_details topics
# 0  To preserve this world for the next generation...     []
# 1  I am wanting to start a petition because the r...     []
# 2  As a multi-million pound consumer industry wit...     []
# 3  I propose increasing the threshold to 60%+ of ...     []
# 4  This is a negative for the country as a whole ...     []

# %%
df.dtypes
# Out:
# created_at            datetime64[ns, UTC]
# action                             object
# background                         object
# additional_details                 object
# topics                             object
# dtype: object

# %%
df.isnull().sum()
# Out:
# created_at               0
# action                   0
# background               0
# additional_details    1997
# topics                   0
# dtype: int64

# %%
df.fillna({'action': '', 'background': '', 'additional_details': ''}, inplace = True)
df.isnull().sum()
# Out:
# created_at            0
# action                0
# background            0
# additional_details    0
# topics                0
# dtype: int64

# %%
df['full_text'] = df['action'].str.cat(df[['background', 'additional_details']], sep = ' ')

# %%
df = df[['created_at', 'full_text', 'topics']]

# %%
df.loc[df['topics'].apply(lambda x: len(x) > 0)]
# Out:
#                             created_at  \
# 0     2020-03-02 12:06:20.235000+00:00
# 1     2020-03-03 11:21:56.566000+00:00
# 2     2020-03-03 11:22:53.628000+00:00
# 3     2020-03-03 11:23:13.336000+00:00
# 4     2020-03-03 11:23:23.361000+00:00
# ...                                ...
# 36954 2022-02-15 10:49:45.037000+00:00
# 36955 2022-02-15 11:05:26.856000+00:00
# 36956 2022-02-15 12:50:28.884000+00:00
# 36957 2022-02-15 14:07:45.190000+00:00
# 36958 2022-02-15 14:39:23.798000+00:00
#
#                                                full_text topics
# 0      Protect the Environment – support carbon neutr...     []
# 1      Bring Hailsham’s roads back to a their former ...     []
# 2      Give holiday caravan/lodge owners the same sta...     []
# 3      Increase the criteria for a successful referen...     []
# 4      Allow conference speakers to be able to speak ...     []
# ...                                                  ...    ...
# 36954  Increase flexible working hours - in order to ...     []
# 36955  create a separate price cap for renewable ener...     []
# 36956  BRING BACK HOT RODS TO KFC MAKE KFC BRING THEM...     []
# 36957  Nasal Spray We need a nasal spray for Autistic...     []
# 36958  scrap the ulez zone scrap the ulez zone it is ...     []
#
# [36959 rows x 3 columns]

# %%
df.at[0, 'topics']
# Out:
# '[]'

# %%
df.loc[df['topics'].apply(lambda x: len(x) > 2)]
# Out:
#                             created_at  \
# 56    2020-03-03 16:38:18.401000+00:00
# 57    2020-03-03 16:59:34.743000+00:00
# 111   2020-03-04 04:40:41.026000+00:00
# 117   2020-03-04 07:53:13.862000+00:00
# 159   2020-03-04 15:11:39.565000+00:00
# ...                                ...
# 36829 2022-02-08 13:21:24.521000+00:00
# 36847 2022-02-08 23:49:33.707000+00:00
# 36854 2022-02-09 12:59:18.741000+00:00
# 36861 2022-02-09 17:23:20.975000+00:00
# 36866 2022-02-09 18:54:37.951000+00:00
#
#                                                full_text  \
# 56     Introduce Mandatory Ethnicity Pay Gap Reportin...
# 57     Suspend sanctions against Iran for the duratio...
# 111    Parliament to protect housing benefit payments...
# 117    Ban spitting in the street especially in light...
# 159    Will the gov support self-employed individuals...
# ...                                                  ...
# 36829  Create an Operation Rescript medal for Armed F...
# 36847  the govt must order a full inquiry into the im...
# 36854  Do not let the government end the legal requir...
# 36861  Confirm all subtopics that will be in 2022 GCS...
# 36866  Backpay the £20 covid uplift to people on Lega...
#
#                       topics
# 56     ['race-and-equality']
# 57              ['covid-19']
# 111             ['covid-19']
# 117             ['covid-19']
# 159             ['covid-19']
# ...                      ...
# 36829           ['covid-19']
# 36847           ['covid-19']
# 36854           ['covid-19']
# 36861           ['covid-19']
# 36866           ['covid-19']
#
# [9282 rows x 3 columns]

# %%
# Set key dates for petitions over a given date range
start_date = pd.to_datetime('2020-04-01')
end_date = pd.to_datetime('2021-03-31')

# %%
# petitions over the financial year of 2020
petitions_2020fy = df.loc[(df.created_at.dt.date >= start_date.date()) & (df.created_at.dt.date <= end_date.date())].copy()
petitions_2020fy.reset_index(drop = True, inplace = True)

# %%
#convert created_at to month commencing
import datetime
month_commencing = petitions_2020fy.pop('created_at')
petitions_2020fy['month_commencing'] = month_commencing.apply(lambda el: pd.Timestamp(datetime.datetime(el.year, el.month, 1)))

# %%
petitions_2020fy.to_csv(r'data/petitions_fiscal_year_2020.csv', index = False)
